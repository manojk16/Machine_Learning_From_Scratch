# %%
import pandas

df1=pandas.read_json("http://pythonhow.com/supermarkets.json")
df1
# Out:
#            Address           City Country  Employees  ID         Name  \
# 0     3666 21st St  San Francisco     USA          8   1      Madeira
# 1   735 Dolores St  San Francisco     USA         15   2  Bready Shop
# 2      332 Hill St  San Francisco     USA         25   3  Super River
# 3     3995 23rd St  San Francisco     USA         10   4   Ben's Shop
# 4  1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 5  551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#               State
# 0          CA 94114
# 1          CA 94119
# 2  California 94114
# 3          CA 94114
# 4        California
# 5          CA 94114

# %%
df2=df1.set_index("Address")
df2
# Out:
#                           City Country  Employees  ID         Name  \
# Address
# 3666 21st St     San Francisco     USA          8   1      Madeira
# 735 Dolores St   San Francisco     USA         15   2  Bready Shop
# 332 Hill St      San Francisco     USA         25   3  Super River
# 3995 23rd St     San Francisco     USA         10   4   Ben's Shop
# 1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#                             State
# Address
# 3666 21st St             CA 94114
# 735 Dolores St           CA 94119
# 332 Hill St      California 94114
# 3995 23rd St             CA 94114
# 1056 Sanchez St        California
# 551 Alvarado St          CA 94114

# %%
#Label Indexing -> Fetching specific Info:
df2.loc["332 Hill St":"1056 Sanchez St","Country":"State"]
# Out:
#                 Country  Employees  ID         Name             State
# Address
# 332 Hill St         USA         25   3  Super River  California 94114
# 3995 23rd St        USA         10   4   Ben's Shop          CA 94114
# 1056 Sanchez St     USA         12   5      Sanchez        California

# %%
list(df2.loc["332 Hill St":,"Country"])
# Out:
# ['USA', 'USA', 'USA', 'USA']

# %%
#data base realted indexing 

df2.iloc[0:5,-1:6]
# Out:
#                             State
# Address
# 3666 21st St             CA 94114
# 735 Dolores St           CA 94119
# 332 Hill St      California 94114
# 3995 23rd St             CA 94114
# 1056 Sanchez St        California

# %%
# combined Indexing 
df2.ix["3666 21st St",2:4]  #ix depreacated
# Out:
# /home/redbend/.local/lib/python3.6/site-packages/ipykernel_launcher.py:2: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
# Employees    8
# ID           1
# Name: 3666 21st St, dtype: object

# %%
df2
# Out:
#                           City Country  Employees  ID         Name  \
# Address
# 3666 21st St     San Francisco     USA          8   1      Madeira
# 735 Dolores St   San Francisco     USA         15   2  Bready Shop
# 332 Hill St      San Francisco     USA         25   3  Super River
# 3995 23rd St     San Francisco     USA         10   4   Ben's Shop
# 1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#                             State
# Address
# 3666 21st St             CA 94114
# 735 Dolores St           CA 94119
# 332 Hill St      California 94114
# 3995 23rd St             CA 94114
# 1056 Sanchez St        California
# 551 Alvarado St          CA 94114

# %%
df3=df2.drop('City',1)# Here 1 means col and ) for rows 
df3
# Out:
#                 Country  Employees  ID         Name             State
# Address
# 3666 21st St        USA          8   1      Madeira          CA 94114
# 735 Dolores St      USA         15   2  Bready Shop          CA 94119
# 332 Hill St         USA         25   3  Super River  California 94114
# 3995 23rd St        USA         10   4   Ben's Shop          CA 94114
# 1056 Sanchez St     USA         12   5      Sanchez        California
# 551 Alvarado St     USA         20   6   Richvalley          CA 94114

# %%
df3
# Out:
#                 Country  Employees  ID         Name             State
# Address
# 3666 21st St        USA          8   1      Madeira          CA 94114
# 735 Dolores St      USA         15   2  Bready Shop          CA 94119
# 332 Hill St         USA         25   3  Super River  California 94114
# 3995 23rd St        USA         10   4   Ben's Shop          CA 94114
# 1056 Sanchez St     USA         12   5      Sanchez        California
# 551 Alvarado St     USA         20   6   Richvalley          CA 94114

# %%
df2
# Out:
#                           City Country  Employees  ID         Name  \
# Address
# 3666 21st St     San Francisco     USA          8   1      Madeira
# 735 Dolores St   San Francisco     USA         15   2  Bready Shop
# 332 Hill St      San Francisco     USA         25   3  Super River
# 3995 23rd St     San Francisco     USA         10   4   Ben's Shop
# 1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#                             State
# Address
# 3666 21st St             CA 94114
# 735 Dolores St           CA 94119
# 332 Hill St      California 94114
# 3995 23rd St             CA 94114
# 1056 Sanchez St        California
# 551 Alvarado St          CA 94114

# %%
df4=df2.drop("3995 23rd St",0)
df4
# Out:
#                           City Country  Employees  ID         Name  \
# Address
# 3666 21st St     San Francisco     USA          8   1      Madeira
# 735 Dolores St   San Francisco     USA         15   2  Bready Shop
# 332 Hill St      San Francisco     USA         25   3  Super River
# 1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#                             State
# Address
# 3666 21st St             CA 94114
# 735 Dolores St           CA 94119
# 332 Hill St      California 94114
# 1056 Sanchez St        California
# 551 Alvarado St          CA 94114

# %%
df5=df2.drop("1056 Sanchez St",0)
df5
# Out:
#                           City Country  Employees  ID         Name  \
# Address
# 3666 21st St     San Francisco     USA          8   1      Madeira
# 735 Dolores St   San Francisco     USA         15   2  Bready Shop
# 332 Hill St      San Francisco     USA         25   3  Super River
# 3995 23rd St     San Francisco     USA         10   4   Ben's Shop
# 551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#                             State
# Address
# 3666 21st St             CA 94114
# 735 Dolores St           CA 94119
# 332 Hill St      California 94114
# 3995 23rd St             CA 94114
# 551 Alvarado St          CA 94114

# %%
df2.drop(df2.index[0:3],0)
# Out:
#                           City Country  Employees  ID        Name       State
# Address
# 3995 23rd St     San Francisco     USA         10   4  Ben's Shop    CA 94114
# 1056 Sanchez St  San Francisco     USA         12   5     Sanchez  California
# 551 Alvarado St  San Francisco     USA         20   6  Richvalley    CA 94114

# %%
df9=df2.drop(df2.index[0:3],0)

# %%
df9
# Out:
#                           City Country  Employees  ID        Name       State
# Address
# 3995 23rd St     San Francisco     USA         10   4  Ben's Shop    CA 94114
# 1056 Sanchez St  San Francisco     USA         12   5     Sanchez  California
# 551 Alvarado St  San Francisco     USA         20   6  Richvalley    CA 94114

# %%
df2
# Out:
#                           City Country  Employees  ID         Name  \
# Address
# 3666 21st St     San Francisco     USA          8   1      Madeira
# 735 Dolores St   San Francisco     USA         15   2  Bready Shop
# 332 Hill St      San Francisco     USA         25   3  Super River
# 3995 23rd St     San Francisco     USA         10   4   Ben's Shop
# 1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#                             State
# Address
# 3666 21st St             CA 94114
# 735 Dolores St           CA 94119
# 332 Hill St      California 94114
# 3995 23rd St             CA 94114
# 1056 Sanchez St        California
# 551 Alvarado St          CA 94114

# %%
#

# %%
df2
# Out:
#                           City Country  Employees  ID         Name  \
# Address
# 3666 21st St     San Francisco     USA          8   1      Madeira
# 735 Dolores St   San Francisco     USA         15   2  Bready Shop
# 332 Hill St      San Francisco     USA         25   3  Super River
# 3995 23rd St     San Francisco     USA         10   4   Ben's Shop
# 1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#                             State
# Address
# 3666 21st St             CA 94114
# 735 Dolores St           CA 94119
# 332 Hill St      California 94114
# 3995 23rd St             CA 94114
# 1056 Sanchez St        California
# 551 Alvarado St          CA 94114

# %%
df2.index
# Out:
# Index(['3666 21st St', '735 Dolores St', '332 Hill St', '3995 23rd St',
#        '1056 Sanchez St', '551 Alvarado St'],
#       dtype='object', name='Address')

# %%
#Lec 101, Add or Modify the column

#df2["Continent"]=["Uttar Pradesh"]
df2.shape
# Out:
# (6, 7)

# %%
df2.shape[0]
# Out:
# 6

# %%
df2["Continent"]=["Uttar Pradesh","Karnataka","Jharkhand","Maharastra","MP","Rajasthan"]
df2["Continent"]=df2.shape[0]*["UP"]
df2
# Out:
#                           City Country  Employees  ID         Name  \
# Address
# 3666 21st St     San Francisco   India          8   1      Madeira
# 735 Dolores St   San Francisco   India         15   2  Bready Shop
# 332 Hill St      San Francisco   India         25   3  Super River
# 3995 23rd St     San Francisco   India         10   4   Ben's Shop
# 1056 Sanchez St  San Francisco   India         12   5      Sanchez
# 551 Alvarado St  San Francisco   India         20   6   Richvalley
#
#                             State Continent
# Address
# 3666 21st St             CA 94114        UP
# 735 Dolores St           CA 94119        UP
# 332 Hill St      California 94114        UP
# 3995 23rd St             CA 94114        UP
# 1056 Sanchez St        California        UP
# 551 Alvarado St          CA 94114        UP

# %%
df2["Continent"]=df2["Country"]+", "+df2["Continent"]
df2
# Out:
#                           City Country  Employees  ID         Name  \
# Address
# 3666 21st St     San Francisco   India          8   1      Madeira
# 735 Dolores St   San Francisco   India         15   2  Bready Shop
# 332 Hill St      San Francisco   India         25   3  Super River
# 3995 23rd St     San Francisco   India         10   4   Ben's Shop
# 1056 Sanchez St  San Francisco   India         12   5      Sanchez
# 551 Alvarado St  San Francisco   India         20   6   Richvalley
#
#                             State  Continent
# Address
# 3666 21st St             CA 94114  India, UP
# 735 Dolores St           CA 94119  India, UP
# 332 Hill St      California 94114  India, UP
# 3995 23rd St             CA 94114  India, UP
# 1056 Sanchez St        California  India, UP
# 551 Alvarado St          CA 94114  India, UP

# %%
df2_t=df2.T
df2_t
# Out:
# Address     3666 21st St 735 Dolores St       332 Hill St   3995 23rd St  \
# City       San Francisco  San Francisco     San Francisco  San Francisco
# Country            India          India             India          India
# Employees              8             15                25             10
# ID                     1              2                 3              4
# Name             Madeira    Bready Shop       Super River     Ben's Shop
# State           CA 94114       CA 94119  California 94114       CA 94114
# Continent      India, UP      India, UP         India, UP      India, UP
#
# Address   1056 Sanchez St 551 Alvarado St
# City        San Francisco   San Francisco
# Country             India           India
# Employees              12              20
# ID                      5               6
# Name              Sanchez      Richvalley
# State          California        CA 94114
# Continent       India, UP       India, UP

# %%
 
df2_t["My Address"]=["MZN","India",100,22208,"Manoj","UP", "Asia"]
df2_t
# Out:
# Address     3666 21st St 735 Dolores St       332 Hill St   3995 23rd St  \
# City       San Francisco  San Francisco     San Francisco  San Francisco
# Country            India          India             India          India
# Employees              8             15                25             10
# ID                     1              2                 3              4
# Name             Madeira    Bready Shop       Super River     Ben's Shop
# State           CA 94114       CA 94119  California 94114       CA 94114
# Continent      India, UP      India, UP         India, UP      India, UP
#
# Address   1056 Sanchez St 551 Alvarado St My Address
# City        San Francisco   San Francisco        MZN
# Country             India           India      India
# Employees              12              20        100
# ID                      5               6      22208
# Name              Sanchez      Richvalley      Manoj
# State          California        CA 94114         UP
# ...

# %%
df3=df2_t.T
df3
# Out:
#                           City Country Employees     ID         Name  \
# Address
# 3666 21st St     San Francisco   India         8      1      Madeira
# 735 Dolores St   San Francisco   India        15      2  Bready Shop
# 332 Hill St      San Francisco   India        25      3  Super River
# 3995 23rd St     San Francisco   India        10      4   Ben's Shop
# 1056 Sanchez St  San Francisco   India        12      5      Sanchez
# 551 Alvarado St  San Francisco   India        20      6   Richvalley
# My Address                 MZN   India       100  22208        Manoj
#
#                             State  Continent
# Address
# 3666 21st St             CA 94114  India, UP
# 735 Dolores St           CA 94119  India, UP
# 332 Hill St      California 94114  India, UP
# 3995 23rd St             CA 94114  India, UP
# 1056 Sanchez St        California  India, UP
# 551 Alvarado St          CA 94114  India, UP
# My Address                     UP       Asia

# %%
df2=df2.drop("3666 21st St",0)
df2
# Out:
#                           City Country  Employees  ID         Name  \
# Address
# 735 Dolores St   San Francisco   India         15   2  Bready Shop
# 332 Hill St      San Francisco   India         25   3  Super River
# 3995 23rd St     San Francisco   India         10   4   Ben's Shop
# 1056 Sanchez St  San Francisco   India         12   5      Sanchez
# 551 Alvarado St  San Francisco   India         20   6   Richvalley
#
#                             State  Continent
# Address
# 735 Dolores St           CA 94119  India, UP
# 332 Hill St      California 94114  India, UP
# 3995 23rd St             CA 94114  India, UP
# 1056 Sanchez St        California  India, UP
# 551 Alvarado St          CA 94114  India, UP

# %%
df2
# Out:
#                           City Country  Employees  ID         Name  \
# Address
# 735 Dolores St   San Francisco   India         15   2  Bready Shop
# 332 Hill St      San Francisco   India         25   3  Super River
# 3995 23rd St     San Francisco   India         10   4   Ben's Shop
# 1056 Sanchez St  San Francisco   India         12   5      Sanchez
# 551 Alvarado St  San Francisco   India         20   6   Richvalley
#
#                             State  Continent
# Address
# 735 Dolores St           CA 94119  India, UP
# 332 Hill St      California 94114  India, UP
# 3995 23rd St             CA 94114  India, UP
# 1056 Sanchez St        California  India, UP
# 551 Alvarado St          CA 94114  India, UP

# %%
#df3=df2.drop(df2.column[0])

# %%
# Lec 103 GeoCoding Address With Panadas and GeoPy

type(df2)
# Out:
# pandas.core.frame.DataFrame

# %%
from geopy.geocoders import ArcGIS
nom=ArcGIS()
nom.geocode("3rd Cross, Anniah Reddy layout, Dodda Banaswadi, Bangalore 560043, India")
# Out:
# Location(3rd Cross Road, Doddabanasawadi, Bangalore, Bengaluru, Karnataka, 560043, (13.016803500000009, 77.65195050000003, 0.0))

# %%
df4=pandas.read_csv("http://pythonhow.com/supermarkets.csv")
df4
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
nom.geocode(df4.Address[0])
# Out:
# Location(Travessa da Santa 21, 4740-451, Santa, Esposende, Braga, (41.609560901504764, -8.73695341564063, 0.0))

# %%
df4["Address"]=df4["Address"]+", "+df4["City"]+", "+df4["State"]+", "+df4["Country"]
df4
# Out:
#    ID                                            Address           City  \
# 0   1         3666 21st St, San Francisco, CA 94114, USA  San Francisco
# 1   2       735 Dolores St, San Francisco, CA 94119, USA  San Francisco
# 2   3  332 Hill St, San Francisco, California 94114, USA  San Francisco
# 3   4         3995 23rd St, San Francisco, CA 94114, USA  San Francisco
# 4   5    1056 Sanchez St, San Francisco, California, USA  San Francisco
# 5   6      551 Alvarado St, San Francisco, CA 94114, USA  San Francisco
#
#               State Country         Name  Employees
# 0          CA 94114     USA      Madeira          8
# 1          CA 94119     USA  Bready Shop         15
# 2  California 94114     USA  Super River         25
# 3          CA 94114     USA   Ben's Shop         10
# 4        California     USA      Sanchez         12
# 5          CA 94114     USA   Richvalley         20

# %%
df4["Coordinates"]=df4["Address"].apply(nom.geocode)

# %%
df4
# Out:
#    ID                                            Address           City  \
# 0   1         3666 21st St, San Francisco, CA 94114, USA  San Francisco
# 1   2       735 Dolores St, San Francisco, CA 94119, USA  San Francisco
# 2   3  332 Hill St, San Francisco, California 94114, USA  San Francisco
# 3   4         3995 23rd St, San Francisco, CA 94114, USA  San Francisco
# 4   5    1056 Sanchez St, San Francisco, California, USA  San Francisco
# 5   6      551 Alvarado St, San Francisco, CA 94114, USA  San Francisco
#
#               State Country         Name  Employees  \
# 0          CA 94114     USA      Madeira          8
# 1          CA 94119     USA  Bready Shop         15
# 2  California 94114     USA  Super River         25
# 3          CA 94114     USA   Ben's Shop         10
# 4        California     USA      Sanchez         12
# 5          CA 94114     USA   Richvalley         20
#
#                                          Coordinates
# ...

# %%
df4["Coordinates"]=df4["Address"].apply(nom.geocode)
df4.Coordinates[0]
# Out:
# Location(3666 21st St, San Francisco, California, 94114, (37.75644449321933, -122.42935314363206, 0.0))

# %%
df4.Coordinates[0].latitude
# Out:
# 37.75644449321933

# %%
df4.Coordinates[0].longitude
# Out:
# -122.42935314363206

# %%
#end of Pandas
